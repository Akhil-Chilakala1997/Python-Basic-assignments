# %%
#ASSignment 2(basic)

# %%
# 1)True,False
# We write them  like below:
# print(bool(0)-False
# print(bool(1))-True


# 2)three differnt  types of boolean operators  are 
# And,Or,Not

# 3)list of truth tables for  a boolean operator:
#     And:
#     1   0   False
#     0    1   True
#     0    0   False
#     1    1   True(Only when  both  conditions are true ..'And' operator gives true otherwise all are false)
    
#     Or:
#     1   0   True
#     0    1  True
#     1    1  True
#     0   0   False (when  both  are false then OR condition will  give  false else it  will  give  true for all condition)
    
#     Not:It gives opposite of the condition True means False ,False ,means  True
#     0 (True)
#     1(False)

# 4)(5 > 4) and (3 == 5)-False
# not (5 > 4)-False
# (5 > 4) or (3 == 5) - True
# not ((5 > 4) or (3 == 5))-False
# (True and True) and (True == False)-False
# (not False) or (not True)-True



# 5)comparison operators:
#     >-greater than
#     <-less than  
#     <=-less than equal  to
#     >=-greater than equal to
#     !=- not equal to
#     ==- equal 


# 6)assignment operator - it  assigns the value to varaiable which was present to its
# left hand side (a=6 ..6 will  be assigned to 'a' and when  you  print 'a' it will  give 6 )
# equal to:it checks the equality  between to values if it is equal  then  it will give true or it will give
#     false(ex:if a==b condition ..condition will  get  exceuted only  a value and b value are equal) )
    


# 7)
# spam = 0
# if spam == 10:
#     (block 1)
#    print('eggs')
# if spam > 5:
#     (block2)
#    print('bacon')
# else:
#     (block 3)
#    print('ham')
#    print('spam')
#    print('spam')




# 8)spam = int(input())
# if spam == 1:
#     print("Hello")
# elif spam == 2:
#     print("Howdy")
# else:
#     print("Greetings!")

# 9)CTRL+C

#10)
# break:if you have break inside  your loop it  will  terminate the loop
# continue:continue skips the code that comes after and the control  is passed back to  start  the loop  
#  for next iteration

#11) for i in range(1,11):
#     print(i)

# i=1
# while i<11:
#     print(i)
#     i=i+1


# 12)import  spam as sp
# sp.bacon()
